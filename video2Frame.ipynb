# %% [markdown]
# ## Cut image from video

# %%
import cv2
import os

def extract_frames(video_path, output_folder):
    # Tạo một đối tượng VideoCapture
    cap = cv2.VideoCapture(video_path)

    # Kiểm tra xem video có được mở thành công không
    if not cap.isOpened():
        print("Không thể mở video.")
        return

    # Tạo thư mục lưu trữ frame nếu nó chưa tồn tại
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Đếm số frame
    frame_count = 0

    # Tần suất frame cắt (1s cắt 25 frame)
    frames_per_second = 20

    # Lấy tổng số frame
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print("Lấy tổng số frame: ",total_frames)
    # Tổng số giây của video
    total_seconds = total_frames / cap.get(cv2.CAP_PROP_FPS)
    print("Tổng số giây của video: ",total_seconds)

    # Tính toán số frame cắt ra cho mỗi giây
    frames_to_cut = frames_per_second * total_seconds
    print("Tính toán số frame cắt ra cho mỗi giây: ",frames_to_cut)
    # Đọc từng frame từ video và lưu vào thư mục
    while True:
        # Đọc một frame
        ret, frame = cap.read()

        # Kiểm tra nếu không còn frame nào hoặc có lỗi xảy ra
        if not ret:
            break

        # Kiểm tra nếu đến điểm cắt frame
        if frame_count % int(total_frames // frames_to_cut) == 0:
            # Ghi frame vào thư mục
            frame_path = os.path.join(output_folder, f"frame1_{frame_count:04d}.jpg")
            cv2.imwrite(frame_path, frame)

        # Tăng biến đếm frame
        frame_count += 1

    # Giải phóng các tài nguyên
    cap.release()
    cv2.destroyAllWindows()


# Sử dụng hàm extract_frames
video_path = '/run/user/1000/gvfs/mtp:host=OPPO_CPH1911_MVTCZSGEEA4H85F6/Bộ nhớ trong dùng chung/DCIM/Camera/VID20240406000829.mp4'
output_folder = 'add'
extract_frames(video_path, output_folder)
# Out:
# Không thể mở video.

# %%
import os
import shutil

# Đường dẫn đến folder nguồn
source_folder = "/media/rambo/HDD/University/DATN/Drowsiness Detection/Data/Data/tets"

# Đường dẫn đến folder đích
destination_folder = "version2/Drowsiness"

# Lặp qua tất cả các tệp trong folder nguồn
for filename in os.listdir(source_folder):
    # Kiểm tra nếu tệp có phần mở rộng là .jpeg
    if filename.endswith(".jpg"):
        # Tạo đường dẫn đầy đủ tới tệp nguồn và tệp đích
        source_path = os.path.join(source_folder, filename)
        destination_path = os.path.join(destination_folder, filename)

        # Di chuyển tệp từ folder nguồn sang folder đích
        shutil.move(source_path, destination_path)
        print(f"Đã chuyển: {filename}")

# %%
video_path1 = '/media/rambo/HDD/University/DATN/Drowsiness Detection/Data/NITYMED/MALE.mp4'
extract_frames(video_path1, output_folder)
# Out:
# Lấy tổng số frame:  6713
# Tổng số giây của video:  268.52
# Tính toán số frame cắt ra cho mỗi giây:  6713.0

# %%
video_path2 = '/media/rambo/HDD/University/DATN/Drowsiness Detection/Data/NITYMED/notdrowsiness.mp4'
output_folder2 = '/media/rambo/HDD/University/DATN/Drowsiness Detection/Data/NITYMED/NotDrowsiness'
extract_frames(video_path2, output_folder2)
# Out:
# Lấy tổng số frame:  12511
# Tổng số giây của video:  500.44
# Tính toán số frame cắt ra cho mỗi giây:  12511.0

# %% [markdown]
# ## Count Image

# %%
import glob
import os

def count_jpg_images(folder_path):
    # Sử dụng glob để tìm tất cả các file JPG trong thư mục
    jpg_files = glob.glob(os.path.join(folder_path, '*.jpg'))
    
    # Đếm số lượng file JPG
    count = len(jpg_files)
    
    return count

# Đường dẫn đến thư mục chứa ảnh
notdrowsiness_folder = 'version2/NotDrowsiness'
drowsiness_folder = 'version2/Drowsiness'

# Gọi hàm để đếm số lượng ảnh JPG trong thư mục
notdrowsiness_count = count_jpg_images(notdrowsiness_folder)
drowsiness_count = count_jpg_images(drowsiness_folder)
# In kết quả
print(f"Số lượng ảnh Drowsiness: {drowsiness_count}")
print(f"Số lượng ảnh not Drowsiness: {notdrowsiness_count}")
# Out:
# Số lượng ảnh Drowsiness: 0
# Số lượng ảnh not Drowsiness: 10362

# %% [markdown]
# ## chuyen anh dang folder khac

# %%
import os
import shutil

def move_images(source_folder, dest_folder, num_images):
    # Đảm bảo rằng thư mục đích tồn tại hoặc tạo mới nếu chưa tồn tại
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Lấy danh sách tệp tin ảnh từ thư mục nguồn
    image_files = [f for f in os.listdir(source_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Chỉ di chuyển số lượng hình ảnh mong muốn
    num_images = min(num_images, len(image_files))

    # Di chuyển từng ảnh đến thư mục đích
    for image in image_files[:num_images]:
        source_path = os.path.join(source_folder, image)
        dest_path = os.path.join(dest_folder, image)
        shutil.move(source_path, dest_path)
        print(f"Đã chuyển {image} đến {dest_folder}")

def main():
    source_folder = "add"
    dest_folder = "data/train/Drowsiness"
    num_images = 600

    move_images(source_folder, dest_folder, num_images)

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Rename Image

# %%
import os

# Đường dẫn đến thư mục
folder_path = "add"

# Lặp qua tất cả các tệp trong thư mục và sắp xếp theo thứ tự tăng dần
file_list = sorted(os.listdir(folder_path))
for idx, filename in enumerate(file_list, start=1):
    if filename.endswith(".jpg"):
        # Đổi tên tệp
        new_filename = f"new_name_{idx}.jpg"
        os.rename(os.path.join(folder_path, filename), os.path.join(folder_path, new_filename))
        print(f"Đã đổi tên: {filename} thành {new_filename}")
# Out:
# Đã đổi tên: frame_0005_new.jpg thành new_name_1.jpg
# Đã đổi tên: frame_0006_new.jpg thành new_name_2.jpg
# Đã đổi tên: frame_0007_new.jpg thành new_name_3.jpg
# Đã đổi tên: frame_0008_new.jpg thành new_name_4.jpg
# Đã đổi tên: frame_0009_new.jpg thành new_name_5.jpg
# Đã đổi tên: frame_0010_new.jpg thành new_name_6.jpg
# Đã đổi tên: frame_0011_new.jpg thành new_name_7.jpg
# Đã đổi tên: frame_0012_new.jpg thành new_name_8.jpg
# Đã đổi tên: frame_0013_new.jpg thành new_name_9.jpg
# Đã đổi tên: frame_0014_new.jpg thành new_name_10.jpg
# Đã đổi tên: frame_0015_new.jpg thành new_name_11.jpg
# Đã đổi tên: frame_0016_new.jpg thành new_name_12.jpg
# Đã đổi tên: frame_0017_new.jpg thành new_name_13.jpg
# Đã đổi tên: frame_0018_new.jpg thành new_name_14.jpg
# Đã đổi tên: frame_0019_new.jpg thành new_name_15.jpg
# Đã đổi tên: frame_0020_new.jpg thành new_name_16.jpg
# Đã đổi tên: frame_0021_new.jpg thành new_name_17.jpg
# Đã đổi tên: frame_0207_new.jpg thành new_name_18.jpg
# Đã đổi tên: frame_0208_new.jpg thành new_name_19.jpg
# Đã đổi tên: frame_0209_new.jpg thành new_name_20.jpg
# Đã đổi tên: frame_0238_new.jpg thành new_name_21.jpg
# Đã đổi tên: frame_0242_new.jpg thành new_name_22.jpg
# Đã đổi tên: frame_0243_new.jpg thành new_name_23.jpg
# Đã đổi tên: frame_0244_new.jpg thành new_name_24.jpg
# Đã đổi tên: frame_0245_new.jpg thành new_name_25.jpg
# Đã đổi tên: frame_0246_new.jpg thành new_name_26.jpg
# Đã đổi tên: frame_0247_new.jpg thành new_name_27.jpg
# Đã đổi tên: frame_0248_new.jpg thành new_name_28.jpg
# Đã đổi tên: frame_0249_new.jpg thành new_name_29.jpg
# Đã đổi tên: frame_0250_new.jpg thành new_name_30.jpg
# Đã đổi tên: frame_0251_new.jpg thành new_name_31.jpg
# Đã đổi tên: frame_0252_new.jpg thành new_name_32.jpg
# Đã đổi tên: frame_0253_new.jpg thành new_name_33.jpg
# Đã đổi tên: frame_0254_new.jpg thành new_name_34.jpg
# Đã đổi tên: frame_0255_new.jpg thành new_name_35.jpg
# Đã đổi tên: frame_0256_new.jpg thành new_name_36.jpg
# Đã đổi tên: frame_0260_new.jpg thành new_name_37.jpg
# Đã đổi tên: frame_0261_new.jpg thành new_name_38.jpg
# Đã đổi tên: frame_0262_new.jpg thành new_name_39.jpg
# Đã đổi tên: frame_0263_new.jpg thành new_name_40.jpg
# Đã đổi tên: frame_0264_new.jpg thành new_name_41.jpg
# Đã đổi tên: frame_0265_new.jpg thành new_name_42.jpg
# Đã đổi tên: frame_0266_new.jpg thành new_name_43.jpg
# Đã đổi tên: frame_0267_new.jpg thành new_name_44.jpg
# Đã đổi tên: frame_0268_new.jpg thành new_name_45.jpg
# Đã đổi tên: frame_0269_new.jpg thành new_name_46.jpg
# Đã đổi tên: frame_0270_new.jpg thành new_name_47.jpg
# Đã đổi tên: frame_0271_new.jpg thành new_name_48.jpg
# Đã đổi tên: frame_0272_new.jpg thành new_name_49.jpg
# Đã đổi tên: frame_0273_new.jpg thành new_name_50.jpg
# Đã đổi tên: frame_0274_new.jpg thành new_name_51.jpg
# Đã đổi tên: frame_0278_new.jpg thành new_name_52.jpg
# Đã đổi tên: frame_0279_new.jpg thành new_name_53.jpg
# Đã đổi tên: frame_0280_new.jpg thành new_name_54.jpg
# Đã đổi tên: frame_0281_new.jpg thành new_name_55.jpg
# Đã đổi tên: frame_0282_new.jpg thành new_name_56.jpg
# Đã đổi tên: frame_0283_new.jpg thành new_name_57.jpg
# Đã đổi tên: frame_0284_new.jpg thành new_name_58.jpg
# Đã đổi tên: frame_0285_new.jpg thành new_name_59.jpg
# Đã đổi tên: frame_0286_new.jpg thành new_name_60.jpg
# Đã đổi tên: frame_0287_new.jpg thành new_name_61.jpg
# Đã đổi tên: frame_0288_new.jpg thành new_name_62.jpg
# Đã đổi tên: frame_0289_new.jpg thành new_name_63.jpg
# Đã đổi tên: frame_0290_new.jpg thành new_name_64.jpg
# Đã đổi tên: frame_0291_new.jpg thành new_name_65.jpg
# Đã đổi tên: frame_0292_new.jpg thành new_name_66.jpg
# Đã đổi tên: frame_0297_new.jpg thành new_name_67.jpg
# Đã đổi tên: frame_0298_new.jpg thành new_name_68.jpg
# Đã đổi tên: frame_0299_new.jpg thành new_name_69.jpg
# Đã đổi tên: frame_0300_new.jpg thành new_name_70.jpg
# Đã đổi tên: frame_0301_new.jpg thành new_name_71.jpg
# Đã đổi tên: frame_0302_new.jpg thành new_name_72.jpg
# Đã đổi tên: frame_0303_new.jpg thành new_name_73.jpg
# Đã đổi tên: frame_0304_new.jpg thành new_name_74.jpg
# Đã đổi tên: frame_0305_new.jpg thành new_name_75.jpg
# Đã đổi tên: frame_0306_new.jpg thành new_name_76.jpg
# Đã đổi tên: frame_0307_new.jpg thành new_name_77.jpg
# Đã đổi tên: frame_0308_new.jpg thành new_name_78.jpg
# Đã đổi tên: frame_0309_new.jpg thành new_name_79.jpg
# Đã đổi tên: frame_0310_new.jpg thành new_name_80.jpg
# Đã đổi tên: frame_0311_new.jpg thành new_name_81.jpg
# Đã đổi tên: frame_0312_new.jpg thành new_name_82.jpg
# Đã đổi tên: frame_0313_new.jpg thành new_name_83.jpg
# Đã đổi tên: frame_0314_new.jpg thành new_name_84.jpg
# Đã đổi tên: frame_0315_new.jpg thành new_name_85.jpg
# Đã đổi tên: frame_0316_new.jpg thành new_name_86.jpg
# Đã đổi tên: frame_0317_new.jpg thành new_name_87.jpg
# Đã đổi tên: frame_0318_new.jpg thành new_name_88.jpg
# Đã đổi tên: frame_0319_new.jpg thành new_name_89.jpg
# Đã đổi tên: frame_0320_new.jpg thành new_name_90.jpg
# Đã đổi tên: frame_0321_new.jpg thành new_name_91.jpg
# Đã đổi tên: frame_0322_new.jpg thành new_name_92.jpg
# Đã đổi tên: frame_0323_new.jpg thành new_name_93.jpg
# Đã đổi tên: frame_0324_new.jpg thành new_name_94.jpg
# Đã đổi tên: frame_0325_new.jpg thành new_name_95.jpg
# Đã đổi tên: frame_0326_new.jpg thành new_name_96.jpg
# Đã đổi tên: frame_0327_new.jpg thành new_name_97.jpg
# Đã đổi tên: frame_0328_new.jpg thành new_name_98.jpg
# Đã đổi tên: frame_0329_new.jpg thành new_name_99.jpg
# Đã đổi tên: frame_0330_new.jpg thành new_name_100.jpg
# Đã đổi tên: frame_0331_new.jpg thành new_name_101.jpg
# Đã đổi tên: frame_0332_new.jpg thành new_name_102.jpg
# Đã đổi tên: frame_0333_new.jpg thành new_name_103.jpg
# Đã đổi tên: frame_0334_new.jpg thành new_name_104.jpg
# Đã đổi tên: frame_0335_new.jpg thành new_name_105.jpg
# Đã đổi tên: frame_0336_new.jpg thành new_name_106.jpg
# Đã đổi tên: frame_0337_new.jpg thành new_name_107.jpg
# Đã đổi tên: frame_0338_new.jpg thành new_name_108.jpg
# Đã đổi tên: frame_0339_new.jpg thành new_name_109.jpg
# Đã đổi tên: frame_0340_new.jpg thành new_name_110.jpg
# Đã đổi tên: frame_0341_new.jpg thành new_name_111.jpg
# Đã đổi tên: frame_0342_new.jpg thành new_name_112.jpg
# Đã đổi tên: frame_0343_new.jpg thành new_name_113.jpg
# Đã đổi tên: frame_0344_new.jpg thành new_name_114.jpg
# Đã đổi tên: frame_0345_new.jpg thành new_name_115.jpg
# Đã đổi tên: frame_0346_new.jpg thành new_name_116.jpg
# Đã đổi tên: frame_0347_new.jpg thành new_name_117.jpg
# Đã đổi tên: frame_0348_new.jpg thành new_name_118.jpg
# Đã đổi tên: frame_0349_new.jpg thành new_name_119.jpg
# Đã đổi tên: frame_0350_new.jpg thành new_name_120.jpg
# Đã đổi tên: frame_0351_new.jpg thành new_name_121.jpg
# Đã đổi tên: frame_0352_new.jpg thành new_name_122.jpg
# Đã đổi tên: frame_0353_new.jpg thành new_name_123.jpg
# Đã đổi tên: frame_0354_new.jpg thành new_name_124.jpg
# Đã đổi tên: frame_0355_new.jpg thành new_name_125.jpg
# Đã đổi tên: frame_0356_new.jpg thành new_name_126.jpg
# Đã đổi tên: frame_0357_new.jpg thành new_name_127.jpg
# Đã đổi tên: frame_0358_new.jpg thành new_name_128.jpg
# Đã đổi tên: frame_0359_new.jpg thành new_name_129.jpg
# Đã đổi tên: frame_0360_new.jpg thành new_name_130.jpg
# Đã đổi tên: frame_0361_new.jpg thành new_name_131.jpg
# Đã đổi tên: frame_0362_new.jpg thành new_name_132.jpg
# Đã đổi tên: frame_0363_new.jpg thành new_name_133.jpg
# Đã đổi tên: frame_0364_new.jpg thành new_name_134.jpg
# Đã đổi tên: frame_0365_new.jpg thành new_name_135.jpg
# Đã đổi tên: frame_0366_new.jpg thành new_name_136.jpg
# Đã đổi tên: frame_0367_new.jpg thành new_name_137.jpg
# Đã đổi tên: frame_0368_new.jpg thành new_name_138.jpg
# Đã đổi tên: frame_0369_new.jpg thành new_name_139.jpg
# Đã đổi tên: frame_0370_new.jpg thành new_name_140.jpg
# Đã đổi tên: frame_0371_new.jpg thành new_name_141.jpg
# Đã đổi tên: frame_0372_new.jpg thành new_name_142.jpg
# Đã đổi tên: frame_0373_new.jpg thành new_name_143.jpg
# Đã đổi tên: frame_0374_new.jpg thành new_name_144.jpg
# Đã đổi tên: frame_0375_new.jpg thành new_name_145.jpg
# Đã đổi tên: frame_0376_new.jpg thành new_name_146.jpg
# Đã đổi tên: frame_0377_new.jpg thành new_name_147.jpg
# Đã đổi tên: frame_0378_new.jpg thành new_name_148.jpg
# Đã đổi tên: frame_0379_new.jpg thành new_name_149.jpg
# Đã đổi tên: frame_0380_new.jpg thành new_name_150.jpg
# Đã đổi tên: frame_0381_new.jpg thành new_name_151.jpg
# Đã đổi tên: frame_0382_new.jpg thành new_name_152.jpg
# Đã đổi tên: frame_0383_new.jpg thành new_name_153.jpg
# Đã đổi tên: frame_0384_new.jpg thành new_name_154.jpg
# Đã đổi tên: frame_0385_new.jpg thành new_name_155.jpg
# Đã đổi tên: frame_0386_new.jpg thành new_name_156.jpg
# Đã đổi tên: frame_0387_new.jpg thành new_name_157.jpg
# Đã đổi tên: frame_0388_new.jpg thành new_name_158.jpg
# Đã đổi tên: frame_0389_new.jpg thành new_name_159.jpg
# Đã đổi tên: frame_0390_new.jpg thành new_name_160.jpg
# Đã đổi tên: frame_0391_new.jpg thành new_name_161.jpg
# Đã đổi tên: frame_0392_new.jpg thành new_name_162.jpg
# Đã đổi tên: frame_0393_new.jpg thành new_name_163.jpg
# Đã đổi tên: frame_0394_new.jpg thành new_name_164.jpg
# Đã đổi tên: frame_0395_new.jpg thành new_name_165.jpg
# Đã đổi tên: frame_0396_new.jpg thành new_name_166.jpg
# Đã đổi tên: frame_0397_new.jpg thành new_name_167.jpg
# Đã đổi tên: frame_0398_new.jpg thành new_name_168.jpg
# Đã đổi tên: frame_0399_new.jpg thành new_name_169.jpg
# Đã đổi tên: frame_0400_new.jpg thành new_name_170.jpg
# Đã đổi tên: frame_0401_new.jpg thành new_name_171.jpg
# Đã đổi tên: frame_0402_new.jpg thành new_name_172.jpg
# Đã đổi tên: frame_0403_new.jpg thành new_name_173.jpg
# Đã đổi tên: frame_0404_new.jpg thành new_name_174.jpg
# Đã đổi tên: frame_0405_new.jpg thành new_name_175.jpg
# Đã đổi tên: frame_0406_new.jpg thành new_name_176.jpg
# Đã đổi tên: frame_0407_new.jpg thành new_name_177.jpg
# Đã đổi tên: frame_0408_new.jpg thành new_name_178.jpg
# Đã đổi tên: frame_0409_new.jpg thành new_name_179.jpg
# Đã đổi tên: frame_0410_new.jpg thành new_name_180.jpg
# Đã đổi tên: frame_0411_new.jpg thành new_name_181.jpg
# Đã đổi tên: frame_0412_new.jpg thành new_name_182.jpg
# Đã đổi tên: frame_0413_new.jpg thành new_name_183.jpg
# Đã đổi tên: frame_0414_new.jpg thành new_name_184.jpg
# Đã đổi tên: frame_0415_new.jpg thành new_name_185.jpg
# Đã đổi tên: frame_0416_new.jpg thành new_name_186.jpg
# Đã đổi tên: frame_0417_new.jpg thành new_name_187.jpg
# Đã đổi tên: frame_0418_new.jpg thành new_name_188.jpg
# Đã đổi tên: frame_0419_new.jpg thành new_name_189.jpg
# Đã đổi tên: frame_0420_new.jpg thành new_name_190.jpg
# Đã đổi tên: frame_0421_new.jpg thành new_name_191.jpg
# Đã đổi tên: frame_0422_new.jpg thành new_name_192.jpg
# Đã đổi tên: frame_0423_new.jpg thành new_name_193.jpg
# Đã đổi tên: frame_0424_new.jpg thành new_name_194.jpg
# Đã đổi tên: frame_0425_new.jpg thành new_name_195.jpg
# Đã đổi tên: frame_0426_new.jpg thành new_name_196.jpg
# Đã đổi tên: frame_0427_new.jpg thành new_name_197.jpg
# Đã đổi tên: frame_0428_new.jpg thành new_name_198.jpg
# Đã đổi tên: frame_0429_new.jpg thành new_name_199.jpg
# Đã đổi tên: frame_0430_new.jpg thành new_name_200.jpg
# Đã đổi tên: frame_0431_new.jpg thành new_name_201.jpg
# Đã đổi tên: frame_0432_new.jpg thành new_name_202.jpg
# Đã đổi tên: frame_0433_new.jpg thành new_name_203.jpg
# Đã đổi tên: frame_0434_new.jpg thành new_name_204.jpg
# Đã đổi tên: frame_0435_new.jpg thành new_name_205.jpg
# Đã đổi tên: frame_0436_new.jpg thành new_name_206.jpg
# Đã đổi tên: frame_0437_new.jpg thành new_name_207.jpg
# Đã đổi tên: frame_0438_new.jpg thành new_name_208.jpg
# Đã đổi tên: frame_0439_new.jpg thành new_name_209.jpg
# Đã đổi tên: frame_0440_new.jpg thành new_name_210.jpg
# Đã đổi tên: frame_0441_new.jpg thành new_name_211.jpg
# Đã đổi tên: frame_0442_new.jpg thành new_name_212.jpg
# Đã đổi tên: frame_0443_new.jpg thành new_name_213.jpg
# Đã đổi tên: frame_0444_new.jpg thành new_name_214.jpg
# Đã đổi tên: frame_0445_new.jpg thành new_name_215.jpg
# Đã đổi tên: frame_0446_new.jpg thành new_name_216.jpg
# Đã đổi tên: frame_0447_new.jpg thành new_name_217.jpg
# Đã đổi tên: frame_0448_new.jpg thành new_name_218.jpg
# Đã đổi tên: frame_0449_new.jpg thành new_name_219.jpg
# Đã đổi tên: frame_0450_new.jpg thành new_name_220.jpg
# Đã đổi tên: frame_0451_new.jpg thành new_name_221.jpg
# Đã đổi tên: frame_0452_new.jpg thành new_name_222.jpg
# Đã đổi tên: frame_0453_new.jpg thành new_name_223.jpg
# Đã đổi tên: frame_0454_new.jpg thành new_name_224.jpg
# Đã đổi tên: frame_0455_new.jpg thành new_name_225.jpg
# Đã đổi tên: frame_0456_new.jpg thành new_name_226.jpg
# Đã đổi tên: frame_0457_new.jpg thành new_name_227.jpg
# Đã đổi tên: frame_0458_new.jpg thành new_name_228.jpg
# Đã đổi tên: frame_0459_new.jpg thành new_name_229.jpg
# Đã đổi tên: frame_0460_new.jpg thành new_name_230.jpg
# Đã đổi tên: frame_0461_new.jpg thành new_name_231.jpg
# Đã đổi tên: frame_0462_new.jpg thành new_name_232.jpg
# Đã đổi tên: frame_0463_new.jpg thành new_name_233.jpg
# Đã đổi tên: frame_0464_new.jpg thành new_name_234.jpg
# Đã đổi tên: frame_0465_new.jpg thành new_name_235.jpg
# Đã đổi tên: frame_0466_new.jpg thành new_name_236.jpg
# Đã đổi tên: frame_0467_new.jpg thành new_name_237.jpg
# Đã đổi tên: frame_0468_new.jpg thành new_name_238.jpg
# Đã đổi tên: frame_0469_new.jpg thành new_name_239.jpg
# Đã đổi tên: frame_0470_new.jpg thành new_name_240.jpg
# Đã đổi tên: frame_0471_new.jpg thành new_name_241.jpg
# Đã đổi tên: frame_0472_new.jpg thành new_name_242.jpg
# Đã đổi tên: frame_0473_new.jpg thành new_name_243.jpg
# Đã đổi tên: frame_0474_new.jpg thành new_name_244.jpg
# Đã đổi tên: frame_0475_new.jpg thành new_name_245.jpg
# Đã đổi tên: frame_0476_new.jpg thành new_name_246.jpg
# Đã đổi tên: frame_0477_new.jpg thành new_name_247.jpg
# Đã đổi tên: frame_0478_new.jpg thành new_name_248.jpg
# Đã đổi tên: frame_0479_new.jpg thành new_name_249.jpg
# Đã đổi tên: frame_0480_new.jpg thành new_name_250.jpg
# Đã đổi tên: frame_0481_new.jpg thành new_name_251.jpg
# Đã đổi tên: frame_0482_new.jpg thành new_name_252.jpg
# Đã đổi tên: frame_0483_new.jpg thành new_name_253.jpg
# Đã đổi tên: frame_0484_new.jpg thành new_name_254.jpg
# Đã đổi tên: frame_0485_new.jpg thành new_name_255.jpg
# Đã đổi tên: frame_0486_new.jpg thành new_name_256.jpg
# Đã đổi tên: frame_0487_new.jpg thành new_name_257.jpg
# Đã đổi tên: frame_0488_new.jpg thành new_name_258.jpg
# Đã đổi tên: frame_0489_new.jpg thành new_name_259.jpg
# Đã đổi tên: frame_0490_new.jpg thành new_name_260.jpg
# Đã đổi tên: frame_0491_new.jpg thành new_name_261.jpg
# Đã đổi tên: frame_0492_new.jpg thành new_name_262.jpg
# Đã đổi tên: frame_0493_new.jpg thành new_name_263.jpg
# Đã đổi tên: frame_0494_new.jpg thành new_name_264.jpg
# Đã đổi tên: frame_0495_new.jpg thành new_name_265.jpg
# Đã đổi tên: frame_0496_new.jpg thành new_name_266.jpg
# Đã đổi tên: frame_0497_new.jpg thành new_name_267.jpg
# Đã đổi tên: frame_0498_new.jpg thành new_name_268.jpg
# Đã đổi tên: frame_0499_new.jpg thành new_name_269.jpg
# Đã đổi tên: frame_0500_new.jpg thành new_name_270.jpg
# Đã đổi tên: frame_0501_new.jpg thành new_name_271.jpg
# Đã đổi tên: frame_0502_new.jpg thành new_name_272.jpg
# Đã đổi tên: frame_0503_new.jpg thành new_name_273.jpg
# Đã đổi tên: frame_0504_new.jpg thành new_name_274.jpg
# Đã đổi tên: frame_0505_new.jpg thành new_name_275.jpg
# Đã đổi tên: frame_0506_new.jpg thành new_name_276.jpg
# Đã đổi tên: frame_0507_new.jpg thành new_name_277.jpg
# Đã đổi tên: frame_0508_new.jpg thành new_name_278.jpg
# Đã đổi tên: frame_0509_new.jpg thành new_name_279.jpg
# Đã đổi tên: frame_0510_new.jpg thành new_name_280.jpg
# Đã đổi tên: frame_0511_new.jpg thành new_name_281.jpg
# Đã đổi tên: frame_0512_new.jpg thành new_name_282.jpg
# Đã đổi tên: frame_0513_new.jpg thành new_name_283.jpg
# Đã đổi tên: frame_0514_new.jpg thành new_name_284.jpg
# Đã đổi tên: frame_0515_new.jpg thành new_name_285.jpg
# Đã đổi tên: frame_0516_new.jpg thành new_name_286.jpg
# Đã đổi tên: frame_0517_new.jpg thành new_name_287.jpg
# Đã đổi tên: frame_0518_new.jpg thành new_name_288.jpg
# Đã đổi tên: frame_0519_new.jpg thành new_name_289.jpg
# Đã đổi tên: frame_0520_new.jpg thành new_name_290.jpg
# Đã đổi tên: frame_0521_new.jpg thành new_name_291.jpg
# Đã đổi tên: frame_0522_new.jpg thành new_name_292.jpg
# Đã đổi tên: frame_0523_new.jpg thành new_name_293.jpg
# Đã đổi tên: frame_0524_new.jpg thành new_name_294.jpg
# Đã đổi tên: frame_0525_new.jpg thành new_name_295.jpg
# Đã đổi tên: frame_0526_new.jpg thành new_name_296.jpg
# Đã đổi tên: frame_0527_new.jpg thành new_name_297.jpg
# Đã đổi tên: frame_0528_new.jpg thành new_name_298.jpg
# Đã đổi tên: frame_0529_new.jpg thành new_name_299.jpg
# Đã đổi tên: frame_0530_new.jpg thành new_name_300.jpg
# Đã đổi tên: frame_0531_new.jpg thành new_name_301.jpg
# Đã đổi tên: frame_0532_new.jpg thành new_name_302.jpg
# Đã đổi tên: frame_0533_new.jpg thành new_name_303.jpg
# Đã đổi tên: frame_0534_new.jpg thành new_name_304.jpg
# Đã đổi tên: frame_0535_new.jpg thành new_name_305.jpg
# Đã đổi tên: frame_0536_new.jpg thành new_name_306.jpg
# Đã đổi tên: frame_0537_new.jpg thành new_name_307.jpg
# Đã đổi tên: frame_0538_new.jpg thành new_name_308.jpg
# Đã đổi tên: frame_0539_new.jpg thành new_name_309.jpg
# Đã đổi tên: frame_0540_new.jpg thành new_name_310.jpg
# Đã đổi tên: frame_0541_new.jpg thành new_name_311.jpg
# Đã đổi tên: frame_0542_new.jpg thành new_name_312.jpg
# Đã đổi tên: frame_0543_new.jpg thành new_name_313.jpg
# Đã đổi tên: frame_0544_new.jpg thành new_name_314.jpg
# Đã đổi tên: frame_0545_new.jpg thành new_name_315.jpg
# Đã đổi tên: frame_0546_new.jpg thành new_name_316.jpg
# Đã đổi tên: frame_0547_new.jpg thành new_name_317.jpg
# Đã đổi tên: frame_0548_new.jpg thành new_name_318.jpg
# Đã đổi tên: frame_0549_new.jpg thành new_name_319.jpg
# Đã đổi tên: frame_0550_new.jpg thành new_name_320.jpg
# Đã đổi tên: frame_0551_new.jpg thành new_name_321.jpg
# Đã đổi tên: frame_0552_new.jpg thành new_name_322.jpg
# Đã đổi tên: frame_0553_new.jpg thành new_name_323.jpg
# Đã đổi tên: frame_0554_new.jpg thành new_name_324.jpg
# Đã đổi tên: frame_0555_new.jpg thành new_name_325.jpg
# Đã đổi tên: frame_0556_new.jpg thành new_name_326.jpg
# Đã đổi tên: frame_0557_new.jpg thành new_name_327.jpg
# Đã đổi tên: frame_0558_new.jpg thành new_name_328.jpg
# Đã đổi tên: frame_0559_new.jpg thành new_name_329.jpg
# Đã đổi tên: frame_0560_new.jpg thành new_name_330.jpg
# Đã đổi tên: frame_0561_new.jpg thành new_name_331.jpg
# Đã đổi tên: frame_0562_new.jpg thành new_name_332.jpg
# Đã đổi tên: frame_0563_new.jpg thành new_name_333.jpg
# Đã đổi tên: frame_0564_new.jpg thành new_name_334.jpg
# Đã đổi tên: frame_0565_new.jpg thành new_name_335.jpg
# Đã đổi tên: frame_0566_new.jpg thành new_name_336.jpg
# Đã đổi tên: frame_0567_new.jpg thành new_name_337.jpg
# Đã đổi tên: frame_0568_new.jpg thành new_name_338.jpg
# Đã đổi tên: frame_0569_new.jpg thành new_name_339.jpg
# Đã đổi tên: frame_0570_new.jpg thành new_name_340.jpg
# Đã đổi tên: frame_0571_new.jpg thành new_name_341.jpg
# Đã đổi tên: frame_0572_new.jpg thành new_name_342.jpg
# Đã đổi tên: frame_0573_new.jpg thành new_name_343.jpg
# Đã đổi tên: frame_0574_new.jpg thành new_name_344.jpg
# Đã đổi tên: frame_0575_new.jpg thành new_name_345.jpg
# Đã đổi tên: frame_0576_new.jpg thành new_name_346.jpg
# Đã đổi tên: frame_0577_new.jpg thành new_name_347.jpg
# Đã đổi tên: frame_0578_new.jpg thành new_name_348.jpg
# Đã đổi tên: frame_0579_new.jpg thành new_name_349.jpg
# Đã đổi tên: frame_0580_new.jpg thành new_name_350.jpg
# Đã đổi tên: frame_0581_new.jpg thành new_name_351.jpg
# Đã đổi tên: frame_0582_new.jpg thành new_name_352.jpg
# Đã đổi tên: frame_0583_new.jpg thành new_name_353.jpg
# Đã đổi tên: frame_0584_new.jpg thành new_name_354.jpg
# Đã đổi tên: frame_0585_new.jpg thành new_name_355.jpg
# Đã đổi tên: frame_0586_new.jpg thành new_name_356.jpg
# Đã đổi tên: frame_0587_new.jpg thành new_name_357.jpg
# Đã đổi tên: frame_0588_new.jpg thành new_name_358.jpg
# Đã đổi tên: frame_0589_new.jpg thành new_name_359.jpg
# Đã đổi tên: frame_0590_new.jpg thành new_name_360.jpg
# Đã đổi tên: frame_0591_new.jpg thành new_name_361.jpg
# Đã đổi tên: frame_0592_new.jpg thành new_name_362.jpg
# Đã đổi tên: frame_0593_new.jpg thành new_name_363.jpg
# Đã đổi tên: frame_0594_new.jpg thành new_name_364.jpg
# Đã đổi tên: frame_0595_new.jpg thành new_name_365.jpg
# Đã đổi tên: frame_0603_new.jpg thành new_name_366.jpg
# Đã đổi tên: frame_0604_new.jpg thành new_name_367.jpg
# Đã đổi tên: frame_0605_new.jpg thành new_name_368.jpg
# Đã đổi tên: frame_0606_new.jpg thành new_name_369.jpg
# Đã đổi tên: frame_0607_new.jpg thành new_name_370.jpg
# Đã đổi tên: frame_0608_new.jpg thành new_name_371.jpg
# Đã đổi tên: frame_0609_new.jpg thành new_name_372.jpg
# Đã đổi tên: frame_0610_new.jpg thành new_name_373.jpg
# Đã đổi tên: frame_0611_new.jpg thành new_name_374.jpg
# Đã đổi tên: frame_0612_new.jpg thành new_name_375.jpg
# Đã đổi tên: frame_0613_new.jpg thành new_name_376.jpg
# Đã đổi tên: frame_0614_new.jpg thành new_name_377.jpg
# Đã đổi tên: frame_0615_new.jpg thành new_name_378.jpg
# Đã đổi tên: frame_0616_new.jpg thành new_name_379.jpg
# Đã đổi tên: frame_0617_new.jpg thành new_name_380.jpg
# Đã đổi tên: frame_0618_new.jpg thành new_name_381.jpg
# Đã đổi tên: frame_0619_new.jpg thành new_name_382.jpg
# Đã đổi tên: frame_0620_new.jpg thành new_name_383.jpg
# Đã đổi tên: frame_0621_new.jpg thành new_name_384.jpg
# Đã đổi tên: frame_0622_new.jpg thành new_name_385.jpg
# Đã đổi tên: frame_0623_new.jpg thành new_name_386.jpg
# Đã đổi tên: frame_0624_new.jpg thành new_name_387.jpg
# Đã đổi tên: frame_0625_new.jpg thành new_name_388.jpg
# Đã đổi tên: frame_0626_new.jpg thành new_name_389.jpg
# Đã đổi tên: frame_0627_new.jpg thành new_name_390.jpg
# Đã đổi tên: frame_0628_new.jpg thành new_name_391.jpg
# Đã đổi tên: frame_0629_new.jpg thành new_name_392.jpg
# Đã đổi tên: frame_0630_new.jpg thành new_name_393.jpg
# Đã đổi tên: frame_0631_new.jpg thành new_name_394.jpg
# Đã đổi tên: frame_0632_new.jpg thành new_name_395.jpg
# Đã đổi tên: frame_0633_new.jpg thành new_name_396.jpg
# Đã đổi tên: frame_0634_new.jpg thành new_name_397.jpg
# Đã đổi tên: frame_0635_new.jpg thành new_name_398.jpg
# Đã đổi tên: frame_0636_new.jpg thành new_name_399.jpg
# Đã đổi tên: frame_0637_new.jpg thành new_name_400.jpg
# Đã đổi tên: frame_0638_new.jpg thành new_name_401.jpg
# Đã đổi tên: frame_0639_new.jpg thành new_name_402.jpg
# Đã đổi tên: frame_0640_new.jpg thành new_name_403.jpg
# Đã đổi tên: frame_0641_new.jpg thành new_name_404.jpg
# Đã đổi tên: frame_0642_new.jpg thành new_name_405.jpg
# Đã đổi tên: frame_0643_new.jpg thành new_name_406.jpg
# Đã đổi tên: frame_0644_new.jpg thành new_name_407.jpg
# Đã đổi tên: frame_0645_new.jpg thành new_name_408.jpg
# Đã đổi tên: frame_0646_new.jpg thành new_name_409.jpg
# Đã đổi tên: frame_0647_new.jpg thành new_name_410.jpg
# Đã đổi tên: frame_0648_new.jpg thành new_name_411.jpg
# Đã đổi tên: frame_0649_new.jpg thành new_name_412.jpg
# Đã đổi tên: frame_0650_new.jpg thành new_name_413.jpg
# Đã đổi tên: frame_0651_new.jpg thành new_name_414.jpg
# Đã đổi tên: frame_0652_new.jpg thành new_name_415.jpg
# Đã đổi tên: frame_0653_new.jpg thành new_name_416.jpg
# Đã đổi tên: frame_0654_new.jpg thành new_name_417.jpg
# Đã đổi tên: frame_0655_new.jpg thành new_name_418.jpg
# Đã đổi tên: frame_0656_new.jpg thành new_name_419.jpg
# Đã đổi tên: frame_0657_new.jpg thành new_name_420.jpg
# Đã đổi tên: frame_0658_new.jpg thành new_name_421.jpg
# Đã đổi tên: frame_0659_new.jpg thành new_name_422.jpg
# Đã đổi tên: frame_0660_new.jpg thành new_name_423.jpg
# Đã đổi tên: frame_0661_new.jpg thành new_name_424.jpg
# Đã đổi tên: frame_0662_new.jpg thành new_name_425.jpg
# Đã đổi tên: frame_0663_new.jpg thành new_name_426.jpg
# Đã đổi tên: frame_0664_new.jpg thành new_name_427.jpg
# Đã đổi tên: frame_0665_new.jpg thành new_name_428.jpg
# Đã đổi tên: frame_0666_new.jpg thành new_name_429.jpg
# Đã đổi tên: frame_0667_new.jpg thành new_name_430.jpg
# Đã đổi tên: frame_0668_new.jpg thành new_name_431.jpg
# Đã đổi tên: frame_0669_new.jpg thành new_name_432.jpg
# Đã đổi tên: frame_0670_new.jpg thành new_name_433.jpg
# Đã đổi tên: frame_0671_new.jpg thành new_name_434.jpg
# Đã đổi tên: frame_0672_new.jpg thành new_name_435.jpg
# Đã đổi tên: frame_0673_new.jpg thành new_name_436.jpg
# Đã đổi tên: frame_0674_new.jpg thành new_name_437.jpg
# Đã đổi tên: frame_0675_new.jpg thành new_name_438.jpg
# Đã đổi tên: frame_0676_new.jpg thành new_name_439.jpg
# Đã đổi tên: frame_0677_new.jpg thành new_name_440.jpg
# Đã đổi tên: frame_0678_new.jpg thành new_name_441.jpg
# Đã đổi tên: frame_0679_new.jpg thành new_name_442.jpg
# Đã đổi tên: frame_0680_new.jpg thành new_name_443.jpg
# Đã đổi tên: frame_0681_new.jpg thành new_name_444.jpg
# Đã đổi tên: frame_0682_new.jpg thành new_name_445.jpg
# Đã đổi tên: frame_0683_new.jpg thành new_name_446.jpg
# Đã đổi tên: frame_0684_new.jpg thành new_name_447.jpg
# Đã đổi tên: frame_0685_new.jpg thành new_name_448.jpg
# Đã đổi tên: frame_0686_new.jpg thành new_name_449.jpg
# Đã đổi tên: frame_0687_new.jpg thành new_name_450.jpg
# Đã đổi tên: frame_0688_new.jpg thành new_name_451.jpg
# Đã đổi tên: frame_0689_new.jpg thành new_name_452.jpg
# Đã đổi tên: frame_0690_new.jpg thành new_name_453.jpg
# Đã đổi tên: frame_0691_new.jpg thành new_name_454.jpg
# Đã đổi tên: frame_0692_new.jpg thành new_name_455.jpg
# Đã đổi tên: frame_0693_new.jpg thành new_name_456.jpg
# Đã đổi tên: frame_0694_new.jpg thành new_name_457.jpg
# Đã đổi tên: frame_0695_new.jpg thành new_name_458.jpg
# Đã đổi tên: frame_0696_new.jpg thành new_name_459.jpg
# Đã đổi tên: frame_0697_new.jpg thành new_name_460.jpg
# Đã đổi tên: frame_0698_new.jpg thành new_name_461.jpg
# Đã đổi tên: frame_0699_new.jpg thành new_name_462.jpg
# Đã đổi tên: frame_0700_new.jpg thành new_name_463.jpg
# Đã đổi tên: frame_0701_new.jpg thành new_name_464.jpg
# Đã đổi tên: frame_0702_new.jpg thành new_name_465.jpg
# Đã đổi tên: frame_0703_new.jpg thành new_name_466.jpg
# Đã đổi tên: frame_0704_new.jpg thành new_name_467.jpg
# Đã đổi tên: frame_0705_new.jpg thành new_name_468.jpg
# Đã đổi tên: frame_0706_new.jpg thành new_name_469.jpg
# Đã đổi tên: frame_0707_new.jpg thành new_name_470.jpg
# Đã đổi tên: frame_0708_new.jpg thành new_name_471.jpg
# Đã đổi tên: frame_0709_new.jpg thành new_name_472.jpg
# Đã đổi tên: frame_0710_new.jpg thành new_name_473.jpg
# Đã đổi tên: frame_0711_new.jpg thành new_name_474.jpg
# Đã đổi tên: frame_0712_new.jpg thành new_name_475.jpg
# Đã đổi tên: frame_0713_new.jpg thành new_name_476.jpg
# Đã đổi tên: frame_0714_new.jpg thành new_name_477.jpg
# Đã đổi tên: frame_0715_new.jpg thành new_name_478.jpg
# Đã đổi tên: frame_0716_new.jpg thành new_name_479.jpg
# Đã đổi tên: frame_0717_new.jpg thành new_name_480.jpg
# Đã đổi tên: frame_0718_new.jpg thành new_name_481.jpg
# Đã đổi tên: frame_0719_new.jpg thành new_name_482.jpg
# Đã đổi tên: frame_0720_new.jpg thành new_name_483.jpg
# Đã đổi tên: frame_0721_new.jpg thành new_name_484.jpg
# Đã đổi tên: frame_0722_new.jpg thành new_name_485.jpg
# Đã đổi tên: frame_0723_new.jpg thành new_name_486.jpg
# Đã đổi tên: frame_0724_new.jpg thành new_name_487.jpg
# Đã đổi tên: frame_0725_new.jpg thành new_name_488.jpg
# Đã đổi tên: frame_0726_new.jpg thành new_name_489.jpg
# Đã đổi tên: frame_0727_new.jpg thành new_name_490.jpg
# Đã đổi tên: frame_0728_new.jpg thành new_name_491.jpg
# Đã đổi tên: frame_0729_new.jpg thành new_name_492.jpg
# Đã đổi tên: frame_0730_new.jpg thành new_name_493.jpg
# Đã đổi tên: frame_0731_new.jpg thành new_name_494.jpg
# Đã đổi tên: frame_0732_new.jpg thành new_name_495.jpg
# Đã đổi tên: frame_0733_new.jpg thành new_name_496.jpg
# Đã đổi tên: frame_0734_new.jpg thành new_name_497.jpg
# Đã đổi tên: frame_0735_new.jpg thành new_name_498.jpg
# Đã đổi tên: frame_0740_new.jpg thành new_name_499.jpg
# Đã đổi tên: frame_0741_new.jpg thành new_name_500.jpg
# Đã đổi tên: frame_0742_new.jpg thành new_name_501.jpg
# Đã đổi tên: frame_0743_new.jpg thành new_name_502.jpg
# Đã đổi tên: frame_0744_new.jpg thành new_name_503.jpg
# Đã đổi tên: frame_0745_new.jpg thành new_name_504.jpg
# Đã đổi tên: frame_0746_new.jpg thành new_name_505.jpg
# Đã đổi tên: frame_0747_new.jpg thành new_name_506.jpg
# Đã đổi tên: frame_0748_new.jpg thành new_name_507.jpg
# Đã đổi tên: frame_0749_new.jpg thành new_name_508.jpg
# Đã đổi tên: frame_0750_new.jpg thành new_name_509.jpg
# Đã đổi tên: frame_0751_new.jpg thành new_name_510.jpg
# Đã đổi tên: frame_0752_new.jpg thành new_name_511.jpg
# Đã đổi tên: frame_0753_new.jpg thành new_name_512.jpg
# Đã đổi tên: frame_0754_new.jpg thành new_name_513.jpg
# Đã đổi tên: frame_0755_new.jpg thành new_name_514.jpg
# Đã đổi tên: frame_0756_new.jpg thành new_name_515.jpg
# Đã đổi tên: frame_0757_new.jpg thành new_name_516.jpg
# Đã đổi tên: frame_0758_new.jpg thành new_name_517.jpg
# Đã đổi tên: frame_0759_new.jpg thành new_name_518.jpg
# Đã đổi tên: frame_0760_new.jpg thành new_name_519.jpg
# Đã đổi tên: frame_0761_new.jpg thành new_name_520.jpg
# Đã đổi tên: frame_0762_new.jpg thành new_name_521.jpg
# Đã đổi tên: frame_0763_new.jpg thành new_name_522.jpg
# Đã đổi tên: frame_0764_new.jpg thành new_name_523.jpg
# Đã đổi tên: frame_0765_new.jpg thành new_name_524.jpg
# Đã đổi tên: frame_0766_new.jpg thành new_name_525.jpg
# Đã đổi tên: frame_0767_new.jpg thành new_name_526.jpg
# Đã đổi tên: frame_0768_new.jpg thành new_name_527.jpg
# Đã đổi tên: frame_0769_new.jpg thành new_name_528.jpg
# Đã đổi tên: frame_0770_new.jpg thành new_name_529.jpg
# Đã đổi tên: frame_0771_new.jpg thành new_name_530.jpg
# Đã đổi tên: frame_0772_new.jpg thành new_name_531.jpg
# Đã đổi tên: frame_0773_new.jpg thành new_name_532.jpg
# Đã đổi tên: frame_0774_new.jpg thành new_name_533.jpg
# Đã đổi tên: frame_0775_new.jpg thành new_name_534.jpg
# Đã đổi tên: frame_0776_new.jpg thành new_name_535.jpg
# Đã đổi tên: frame_0777_new.jpg thành new_name_536.jpg
# Đã đổi tên: frame_0778_new.jpg thành new_name_537.jpg
# Đã đổi tên: frame_0779_new.jpg thành new_name_538.jpg
# Đã đổi tên: frame_0780_new.jpg thành new_name_539.jpg
# Đã đổi tên: frame_0781_new.jpg thành new_name_540.jpg
# Đã đổi tên: frame_0782_new.jpg thành new_name_541.jpg
# Đã đổi tên: frame_0783_new.jpg thành new_name_542.jpg
# Đã đổi tên: frame_0784_new.jpg thành new_name_543.jpg
# Đã đổi tên: frame_0785_new.jpg thành new_name_544.jpg
# Đã đổi tên: frame_0786_new.jpg thành new_name_545.jpg
# Đã đổi tên: frame_0787_new.jpg thành new_name_546.jpg
# Đã đổi tên: frame_0788_new.jpg thành new_name_547.jpg
# Đã đổi tên: frame_0789_new.jpg thành new_name_548.jpg
# Đã đổi tên: frame_0790_new.jpg thành new_name_549.jpg
# Đã đổi tên: frame_0791_new.jpg thành new_name_550.jpg
# Đã đổi tên: frame_0792_new.jpg thành new_name_551.jpg
# Đã đổi tên: frame_0793_new.jpg thành new_name_552.jpg
# Đã đổi tên: frame_0794_new.jpg thành new_name_553.jpg
# Đã đổi tên: frame_0795_new.jpg thành new_name_554.jpg
# Đã đổi tên: frame_0796_new.jpg thành new_name_555.jpg
# Đã đổi tên: frame_0797_new.jpg thành new_name_556.jpg
# Đã đổi tên: frame_0798_new.jpg thành new_name_557.jpg
# Đã đổi tên: frame_0799_new.jpg thành new_name_558.jpg
# Đã đổi tên: frame_0800_new.jpg thành new_name_559.jpg
# Đã đổi tên: frame_0801_new.jpg thành new_name_560.jpg
# Đã đổi tên: frame_0802_new.jpg thành new_name_561.jpg
# Đã đổi tên: frame_0803_new.jpg thành new_name_562.jpg
# Đã đổi tên: frame_0804_new.jpg thành new_name_563.jpg
# Đã đổi tên: frame_0805_new.jpg thành new_name_564.jpg
# Đã đổi tên: frame_0806_new.jpg thành new_name_565.jpg
# Đã đổi tên: frame_0807_new.jpg thành new_name_566.jpg
# Đã đổi tên: frame_0808_new.jpg thành new_name_567.jpg
# Đã đổi tên: frame_0809_new.jpg thành new_name_568.jpg
# Đã đổi tên: frame_0810_new.jpg thành new_name_569.jpg
# Đã đổi tên: frame_0811_new.jpg thành new_name_570.jpg
# Đã đổi tên: frame_0812_new.jpg thành new_name_571.jpg
# Đã đổi tên: frame_0813_new.jpg thành new_name_572.jpg
# Đã đổi tên: frame_0814_new.jpg thành new_name_573.jpg
# Đã đổi tên: frame_0815_new.jpg thành new_name_574.jpg
# Đã đổi tên: frame_0816_new.jpg thành new_name_575.jpg
# Đã đổi tên: frame_0817_new.jpg thành new_name_576.jpg
# Đã đổi tên: images (1)_new.jpg thành new_name_577.jpg
# Đã đổi tên: images (10)_new.jpg thành new_name_578.jpg
# Đã đổi tên: images (11)_new.jpg thành new_name_579.jpg
# Đã đổi tên: images (12)_new.jpg thành new_name_580.jpg
# Đã đổi tên: images (13)_new.jpg thành new_name_581.jpg
# Đã đổi tên: images (14)_new.jpg thành new_name_582.jpg
# Đã đổi tên: images (15)_new.jpg thành new_name_583.jpg
# Đã đổi tên: images (16)_new.jpg thành new_name_584.jpg
# Đã đổi tên: images (17)_new.jpg thành new_name_585.jpg
# Đã đổi tên: images (18)_new.jpg thành new_name_586.jpg
# Đã đổi tên: images (19)_new.jpg thành new_name_587.jpg
# Đã đổi tên: images (2)_new.jpg thành new_name_588.jpg
# Đã đổi tên: images (20)_new.jpg thành new_name_589.jpg
# Đã đổi tên: images (21)_new.jpg thành new_name_590.jpg
# Đã đổi tên: images (22)_new.jpg thành new_name_591.jpg
# Đã đổi tên: images (23)_new.jpg thành new_name_592.jpg
# Đã đổi tên: images (24)_new.jpg thành new_name_593.jpg
# Đã đổi tên: images (25)_new.jpg thành new_name_594.jpg
# Đã đổi tên: images (26)_new.jpg thành new_name_595.jpg
# Đã đổi tên: images (27)_new.jpg thành new_name_596.jpg
# Đã đổi tên: images (28)_new.jpg thành new_name_597.jpg
# Đã đổi tên: images (29)_new.jpg thành new_name_598.jpg
# Đã đổi tên: images (3)_new.jpg thành new_name_599.jpg
# Đã đổi tên: images (30)_new.jpg thành new_name_600.jpg
# Đã đổi tên: images (31)_new.jpg thành new_name_601.jpg
# Đã đổi tên: images (32)_new.jpg thành new_name_602.jpg
# Đã đổi tên: images (33)_new.jpg thành new_name_603.jpg
# Đã đổi tên: images (34)_new.jpg thành new_name_604.jpg
# Đã đổi tên: images (35)_new.jpg thành new_name_605.jpg
# Đã đổi tên: images (36)_new.jpg thành new_name_606.jpg
# Đã đổi tên: images (37)_new.jpg thành new_name_607.jpg
# Đã đổi tên: images (38)_new.jpg thành new_name_608.jpg
# Đã đổi tên: images (39)_new.jpg thành new_name_609.jpg
# Đã đổi tên: images (4)_new.jpg thành new_name_610.jpg
# Đã đổi tên: images (40)_new.jpg thành new_name_611.jpg
# Đã đổi tên: images (41)_new.jpg thành new_name_612.jpg
# Đã đổi tên: images (42)_new.jpg thành new_name_613.jpg
# Đã đổi tên: images (43)_new.jpg thành new_name_614.jpg
# Đã đổi tên: images (44)_new.jpg thành new_name_615.jpg
# Đã đổi tên: images (45)_new.jpg thành new_name_616.jpg
# Đã đổi tên: images (46)_new.jpg thành new_name_617.jpg
# Đã đổi tên: images (47)_new.jpg thành new_name_618.jpg
# Đã đổi tên: images (48)_new.jpg thành new_name_619.jpg
# Đã đổi tên: images (49)_new.jpg thành new_name_620.jpg
# Đã đổi tên: images (5)_new.jpg thành new_name_621.jpg
# Đã đổi tên: images (50)_new.jpg thành new_name_622.jpg
# Đã đổi tên: images (51)_new.jpg thành new_name_623.jpg
# Đã đổi tên: images (52)_new.jpg thành new_name_624.jpg
# Đã đổi tên: images (53)_new.jpg thành new_name_625.jpg
# Đã đổi tên: images (54)_new.jpg thành new_name_626.jpg
# Đã đổi tên: images (55)_new.jpg thành new_name_627.jpg
# Đã đổi tên: images (56)_new.jpg thành new_name_628.jpg
# Đã đổi tên: images (57)_new.jpg thành new_name_629.jpg
# Đã đổi tên: images (58)_new.jpg thành new_name_630.jpg
# Đã đổi tên: images (59)_new.jpg thành new_name_631.jpg
# Đã đổi tên: images (6)_new.jpg thành new_name_632.jpg
# Đã đổi tên: images (60)_new.jpg thành new_name_633.jpg
# Đã đổi tên: images (61)_new.jpg thành new_name_634.jpg
# Đã đổi tên: images (62)_new.jpg thành new_name_635.jpg
# Đã đổi tên: images (63)_new.jpg thành new_name_636.jpg
# Đã đổi tên: images (64)_new.jpg thành new_name_637.jpg
# Đã đổi tên: images (65)_new.jpg thành new_name_638.jpg
# Đã đổi tên: images (66)_new.jpg thành new_name_639.jpg
# Đã đổi tên: images (67)_new.jpg thành new_name_640.jpg
# Đã đổi tên: images (68)_new.jpg thành new_name_641.jpg
# Đã đổi tên: images (69)_new.jpg thành new_name_642.jpg
# Đã đổi tên: images (7)_new.jpg thành new_name_643.jpg
# Đã đổi tên: images (70)_new.jpg thành new_name_644.jpg
# Đã đổi tên: images (71)_new.jpg thành new_name_645.jpg
# Đã đổi tên: images (72)_new.jpg thành new_name_646.jpg
# Đã đổi tên: images (73)_new.jpg thành new_name_647.jpg
# Đã đổi tên: images (74)_new.jpg thành new_name_648.jpg
# Đã đổi tên: images (75)_new.jpg thành new_name_649.jpg
# Đã đổi tên: images (76)_new.jpg thành new_name_650.jpg
# Đã đổi tên: images (77)_new.jpg thành new_name_651.jpg
# Đã đổi tên: images (78)_new.jpg thành new_name_652.jpg
# Đã đổi tên: images (79)_new.jpg thành new_name_653.jpg
# Đã đổi tên: images (8)_new.jpg thành new_name_654.jpg
# Đã đổi tên: images (80)_new.jpg thành new_name_655.jpg
# Đã đổi tên: images (81)_new.jpg thành new_name_656.jpg
# Đã đổi tên: images (82)_new.jpg thành new_name_657.jpg
# Đã đổi tên: images (83)_new.jpg thành new_name_658.jpg
# Đã đổi tên: images (9)_new.jpg thành new_name_659.jpg
# Đã đổi tên: images_new.jpg thành new_name_660.jpg

# %% [markdown]
# ## Landmark image

# %%
import cv2
import mediapipe as mp

# # Khởi tạo đối tượng Mediapipe
# mp_face_mesh = mp.solutions.face_mesh

# # Đọc ảnh
# image = cv2.imread('frame1_0.jpg')

# # Khởi tạo bộ xử lý nhận diện landmark khuôn mặt
# with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, min_detection_confidence=0.5) as face_mesh:
#     # Chuyển đổi ảnh sang định dạng RGB
#     image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     # Nhận diện landmark trên khuôn mặt
#     results = face_mesh.process(image_rgb)

#     # Vẽ landmark lên ảnh
#     if results.multi_face_landmarks:
#         for face_landmarks in results.multi_face_landmarks:
#             for landmark in face_landmarks.landmark:
#                 cx, cy = int(landmark.x * image.shape[1]), int(landmark.y * image.shape[0])
#                 cv2.circle(image, (cx, cy), 1, (0, 255, 0), -1)

#     # Hiển thị ảnh kết quả
#     cv2.imshow('Image with Face Landmarks', image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import time

def get_landmarks(image_path):
    start1 = time.time()
    # Left eyes indices 
    Points =[ 46, 111, 276, 448]

    # Tạo đối tượng của lớp Mediapipe EyeLandmark
    mp_eye_landmarks = mp.solutions.face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1)

    # Đọc ảnh
    image = cv2.imread(image_path)

    # Chuyển đổi ảnh sang không gian màu RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Nhận diện landmarks của khuôn mặt trên ảnh
    results = mp_eye_landmarks.process(image_rgb)

    # Kiểm tra xem có landmarks nào được nhận diện không
    if results.multi_face_landmarks:
        # Lấy danh sách các landmarks của khuôn mặt đầu tiên trong ảnh
        face_landmarks = results.multi_face_landmarks[0]

        # Tạo danh sách tọa độ của các điểm LEFT_EYE
        points_landmarks = []

        for index in Points:
            landmark = face_landmarks.landmark[index]
            landmark_x = int(landmark.x * image.shape[1])
            landmark_y = int(landmark.y * image.shape[0])
            points_landmarks.append((landmark_x, landmark_y))

            # print(f"Landmark {index}: ({landmark_x}, {landmark_y})")

        # Vẽ một hình tròn đỏ tại mỗi điểm LEFT_EYE trên ảnh
        for landmark in points_landmarks:
            cv2.circle(image, landmark, 1, (0, 0, 255), -1)    

    # image = cv2.imread("frame1_0.jpg")
    # start_px = min(points_landmarks[0][0],points_landmarks[1][0])
    # start_py = min(points_landmarks[0][1],points_landmarks[2][1])
    # end_px = max(points_landmarks[2][0],points_landmarks[3][0])
    # end_py = max(points_landmarks[1][1],points_landmarks[3][1])
    # cropped_image = image[start_py:end_py, start_px:end_px]
    # cv2.imwrite("test.jpg", cropped_image)

    # Hiển thị ảnh kết quả
    end1 = time.time() - start1
    print("Time: ",end1)
    cv2.imshow("Landmarks", image)
    cv2.imwrite("test.jpg",image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    return points_landmarks


img_path = r"/media/rambo/HDD/University/DATN/Drowsiness Detection/Code/23032024/Drowsiness.jpg"
A = get_landmarks(img_path)

# %%
# Points =[ 63, 117, 293, 346]
A
# Out:
# [(906, 727), (900, 838), (1415, 646), (1395, 753)]

# %%
import cv2
import mediapipe as mp

# Khởi tạo Face Mesh detection
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

# Khởi tạo webcam
cap = cv2.VideoCapture(0)

# Kích thước của vùng cắt
cut_size = (224, 224)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # frame = cv2.imread('frame_0000.jpg')
    # Chuyển đổi ảnh sang không gian màu RGB (Mediapipe yêu cầu đầu vào là RGB)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Nhận diện landmark trên khuôn mặt
    with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1) as face_mesh:
        results = face_mesh.process(frame_rgb)
        if results.multi_face_landmarks:
            # Tính toán tọa độ của các điểm cần cắt cho vùng 1
            points_to_cut1 = [464, 443, 265, 450]
            landmarks = results.multi_face_landmarks[0].landmark
            min_x1 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
            min_y1 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut1)
            max_x1 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
            max_y1 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut1)

            # Tính toán tọa độ của các điểm cần cắt cho vùng 2
            points_to_cut2 = [124, 223, 244, 230]
            min_x2 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
            min_y2 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut2)
            max_x2 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
            max_y2 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut2)

            # Cắt vùng mắt từ ảnh và resize về kích thước 224x224
            cut_region1 = frame[int(min_y1):int(max_y1), int(min_x1):int(max_x1)]
            resized_cut_region1 = cv2.resize(cut_region1, cut_size)

            cut_region2 = frame[int(min_y2):int(max_y2), int(min_x2):int(max_x2)]
            resized_cut_region2 = cv2.resize(cut_region2, cut_size)

            # Hiển thị vùng cắt đã resize
            # cv2.imshow("Resized Cut Region 1", resized_cut_region1)
            # cv2.imshow("Resized Cut Region 2", resized_cut_region2)

            # Ghép lại các vùng cắt đã resize
            merged_image = cv2.hconcat([resized_cut_region2, resized_cut_region1])

            # Hiển thị ảnh đã ghép
            cv2.imshow("Merged Image", merged_image)

    # Hiển thị frame gốc
    cv2.imshow("Frame", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
# one image
# Chuyển đổi ảnh sang không gian màu RGB (Mediapipe yêu cầu đầu vào là RGB)
frame = cv2.imread('frame_0000.jpg')
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# Khởi tạo Face Mesh detection
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils
cut_size = (224, 224)


# Nhận diện landmark trên khuôn mặt
with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1) as face_mesh:
    results = face_mesh.process(frame_rgb)
    if results.multi_face_landmarks:
        # Tính toán tọa độ của các điểm cần cắt cho vùng 1
        points_to_cut1 = [464, 443, 265, 450]
        landmarks = results.multi_face_landmarks[0].landmark
        min_x1 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
        min_y1 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut1)
        max_x1 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
        max_y1 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut1)

        # Tính toán tọa độ của các điểm cần cắt cho vùng 2
        points_to_cut2 = [124, 223, 244, 230]
        min_x2 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
        min_y2 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut2)
        max_x2 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
        max_y2 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut2)

        # Cắt vùng mắt từ ảnh và resize về kích thước 224x224
        cut_region1 = frame[int(min_y1):int(max_y1), int(min_x1):int(max_x1)]
        resized_cut_region1 = cv2.resize(cut_region1, cut_size)

        cut_region2 = frame[int(min_y2):int(max_y2), int(min_x2):int(max_x2)]
        resized_cut_region2 = cv2.resize(cut_region2, cut_size)

        # Hiển thị vùng cắt đã resize
        cv2.imshow("Resized Cut Region 1", resized_cut_region1)
        # cv2.imshow("Resized Cut Region 2", resized_cut_region2)

        # Ghép lại các vùng cắt đã resize
        # merged_image = cv2.hconcat([resized_cut_region2, resized_cut_region1])

        # # Hiển thị ảnh đã ghép
        # cv2.imshow("Merged Image", merged_image)

# %% [markdown]
# ## Extract eye version 1

# %%
import cv2
import mediapipe as mp
import os
import time

# def get_landmarks(image_path):
#     # start1 = time.time()
#     # Left eyes indices 
#     Points =[ 63, 117, 293, 346]

#     # Tạo đối tượng của lớp Mediapipe EyeLandmark
#     mp_eye_landmarks = mp.solutions.face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1)

#     # Đọc ảnh
#     image = cv2.imread(image_path)

#     # Chuyển đổi ảnh sang không gian màu RGB
#     image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Nhận diện landmarks của khuôn mặt trên ảnh
#     results = mp_eye_landmarks.process(image_rgb)

#     # Kiểm tra xem có landmarks nào được nhận diện không
#     if results.multi_face_landmarks:
#         # Lấy danh sách các landmarks của khuôn mặt đầu tiên trong ảnh
#         face_landmarks = results.multi_face_landmarks[0]

#         # Tạo danh sách tọa độ của các điểm LEFT_EYE
#         points_landmarks = []

#         for index in Points:
#             landmark = face_landmarks.landmark[index]
#             landmark_x = int(landmark.x * image.shape[1])
#             landmark_y = int(landmark.y * image.shape[0])
#             points_landmarks.append((landmark_x, landmark_y))

#         # Vẽ một hình tròn đỏ tại mỗi điểm LEFT_EYE trên ảnh
#         # for landmark in points_landmarks:
#         #     cv2.circle(image, landmark, 1, (0, 0, 255), -1)  

#     start_px = min(points_landmarks[0][0],points_landmarks[1][0])
#     start_py = min(points_landmarks[0][1],points_landmarks[2][1])
#     end_px = max(points_landmarks[2][0],points_landmarks[3][0])
#     end_py = max(points_landmarks[1][1],points_landmarks[3][1])
#     cropped_image = image[start_py:end_py, start_px:end_px]  

#     # Tạo tên file lưu sau khi sửa đổi (cùng tên với file gốc)
#     img_name = os.path.basename(image_path)
#     output_path = os.path.join("NotDrowsiness", img_name)

#     # Lưu ảnh sau khi sửa đổi
#     cv2.imwrite(output_path, cropped_image)

#     # Hiển thị ảnh kết quả
#     # end1 = time.time() - start1
#     # print("Time: ", end1)
#     # cv2.imshow("Landmarks", image)
#     # cv2.waitKey(0)
#     # cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import os
import time

# def get_landmarks(image_path):
#     # start1 = time.time()
#     # Left eyes indices 
#     Points =[ 63, 117, 293, 346]

#     # Tạo đối tượng của lớp Mediapipe EyeLandmark
#     mp_eye_landmarks = mp.solutions.face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1)

#     # Đọc ảnh
#     image = cv2.imread(image_path)

#     # Chuyển đổi ảnh sang không gian màu RGB
#     image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Nhận diện landmarks của khuôn mặt trên ảnh
#     results = mp_eye_landmarks.process(image_rgb)

#     # Kiểm tra xem có landmarks nào được nhận diện không
#     if results.multi_face_landmarks:
#         # Lấy danh sách các landmarks của khuôn mặt đầu tiên trong ảnh
#         face_landmarks = results.multi_face_landmarks[0]

#         # Tạo danh sách tọa độ của các điểm LEFT_EYE
#         points_landmarks = []

#         for index in Points:
#             landmark = face_landmarks.landmark[index]
#             landmark_x = int(landmark.x * image.shape[1])
#             landmark_y = int(landmark.y * image.shape[0])
#             points_landmarks.append((landmark_x, landmark_y))

#         # Vẽ một hình tròn đỏ tại mỗi điểm LEFT_EYE trên ảnh
#         # for landmark in points_landmarks:
#         #     cv2.circle(image, landmark, 1, (0, 0, 255), -1)  

#     start_px = min(points_landmarks[0][0],points_landmarks[1][0])
#     start_py = min(points_landmarks[0][1],points_landmarks[2][1])
#     end_px = max(points_landmarks[2][0],points_landmarks[3][0])
#     end_py = max(points_landmarks[1][1],points_landmarks[3][1])
#     cropped_image = image[start_py:end_py, start_px:end_px]  

#     # Tạo tên file lưu sau khi sửa đổi (cùng tên với file gốc)
#     img_name = os.path.basename(image_path)
#     output_path = os.path.join("NotDrowsiness", img_name)

#     # Lưu ảnh sau khi sửa đổi
#     cv2.imwrite(output_path, cropped_image)

#     # Hiển thị ảnh kết quả
#     # end1 = time.time() - start1
#     # print("Time: ", end1)
#     # cv2.imshow("Landmarks", image)
#     # cv2.waitKey(0)
#     # cv2.destroyAllWindows()

# Thư mục chứa ảnh
folder_path = "/media/rambo/HDD/University/DATN/Drowsiness Detection/Data/NITYMED/NotDrowsiness"
Points =[ 63, 117, 293, 346]
mp_eye_landmarks = mp.solutions.face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1)

# Duyệt qua tất cả các file trong thư mục và xử lý chúng
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") :
        image_path = os.path.join(folder_path, filename)
        points_landmarks = []
        # Đọc ảnh
        image = cv2.imread(image_path)

        # Chuyển đổi ảnh sang không gian màu RGB
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Nhận diện landmarks của khuôn mặt trên ảnh
        results = mp_eye_landmarks.process(image_rgb)

        # Kiểm tra xem có landmarks nào được nhận diện không
        if results.multi_face_landmarks:
            # Lấy danh sách các landmarks của khuôn mặt đầu tiên trong ảnh
            face_landmarks = results.multi_face_landmarks[0]

            # Tạo danh sách tọa độ của các điểm LEFT_EYE
            

            for index in Points:
                landmark = face_landmarks.landmark[index]
                landmark_x = int(landmark.x * image.shape[1])
                landmark_y = int(landmark.y * image.shape[0])
                points_landmarks.append((landmark_x, landmark_y))

            # Vẽ một hình tròn đỏ tại mỗi điểm LEFT_EYE trên ảnh
            # for landmark in points_landmarks:
            #     cv2.circle(image, landmark, 1, (0, 0, 255), -1)  

            start_px = min(points_landmarks[0][0],points_landmarks[1][0])
            start_py = min(points_landmarks[0][1],points_landmarks[2][1])
            end_px = max(points_landmarks[2][0],points_landmarks[3][0])
            end_py = max(points_landmarks[1][1],points_landmarks[3][1])
            cropped_image = image[start_py:end_py, start_px:end_px]  

            # Tạo tên file lưu sau khi sửa đổi (cùng tên với file gốc)
            img_name = os.path.basename(image_path)
            output_path = os.path.join("NotDrowsiness", img_name)

            # Lưu ảnh sau khi sửa đổi
            cv2.imwrite(output_path, cropped_image)
        else:
            print(img_name)
# Out:
# I0000 00:00:1712173873.682231   10486 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712173873.683394   13168 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# frame_2585.jpg

# %% [markdown]
# ## extract eye version 2

# %%
import os
import cv2
import mediapipe as mp

# Thư mục chứa ảnh
folder_path = "add"
points_to_cut1 = [464, 443, 265, 450]
points_to_cut2 = [124, 223, 244, 230]
cut_size = (224, 224)

# Khởi tạo Face Mesh detection
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

# Duyệt qua tất cả các file trong thư mục và xử lý chúng
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") :
        image_path = os.path.join(folder_path, filename)
        points_landmarks = []
        # Đọc ảnh
        frame = cv2.imread(image_path)

        # Chuyển đổi ảnh sang không gian màu RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Nhận diện landmark trên khuôn mặt
        with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1) as face_mesh:
            results = face_mesh.process(frame_rgb)
            if results.multi_face_landmarks:
                # Tính toán tọa độ của các điểm cần cắt cho vùng 1
               
                landmarks = results.multi_face_landmarks[0].landmark
                min_x1 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
                min_y1 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut1)
                max_x1 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut1)
                max_y1 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut1)

                # Tính toán tọa độ của các điểm cần cắt cho vùng 2
               
                min_x2 = min(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
                min_y2 = min(landmarks[i].y * frame.shape[0] for i in points_to_cut2)
                max_x2 = max(landmarks[i].x * frame.shape[1] for i in points_to_cut2)
                max_y2 = max(landmarks[i].y * frame.shape[0] for i in points_to_cut2)

                # Cắt vùng mắt từ ảnh và resize về kích thước 224x224
                cut_region1 = frame[int(min_y1):int(max_y1), int(min_x1):int(max_x1)]
                resized_cut_region1 = cv2.resize(cut_region1, cut_size)

                cut_region2 = frame[int(min_y2):int(max_y2), int(min_x2):int(max_x2)]
                resized_cut_region2 = cv2.resize(cut_region2, cut_size)

                # Hiển thị vùng cắt đã resize
                # cv2.imshow("Resized Cut Region 1", resized_cut_region1)
                # cv2.imshow("Resized Cut Region 2", resized_cut_region2)
                # cv2.waitKey(0)

                # Ghép lại các vùng cắt đã resize
                merged_image = cv2.hconcat([resized_cut_region2, resized_cut_region1])

                # Tạo tên file lưu sau khi sửa đổi (cùng tên với file gốc)
                img_name = os.path.basename(image_path)
                output_path = os.path.join("add", img_name)

                # Lưu ảnh sau khi sửa đổi
                cv2.imwrite(output_path, merged_image)
            else:
                print(img_name)
# Out:
# I0000 00:00:1712341389.193131  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.195527  707631 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.282631  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.284414  707642 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.338702  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.339620  707653 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.396897  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.397938  707664 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.454388  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.458487  707675 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.517305  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.518257  707686 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.565317  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.566486  707697 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.629647  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.630686  707708 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.681664  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.682703  707719 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.755881  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.756840  707731 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.808297  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.809288  707742 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.882193  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.883281  707753 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.935219  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.936149  707764 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341389.993700  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341389.994949  707775 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.043245  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.044282  707786 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.099692  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.100628  707797 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.151002  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.151937  707808 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.206334  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.207365  707820 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.253136  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.254107  707831 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.308817  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.309871  707842 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.357021  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.358016  707853 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.408637  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.409658  707864 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.455640  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.456554  707875 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.508528  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.509661  707886 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.560243  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.561141  707897 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.614016  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.615084  707908 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.663978  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.665273  707919 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.722869  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.723760  707930 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.770822  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.771766  707941 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.833937  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.835317  707952 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.885893  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.886932  707963 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341390.993705  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341390.994663  707974 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.043885  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.044741  707985 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.111167  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.112155  707996 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.161056  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.162013  708008 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.214964  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.216025  708019 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.262416  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.263431  708030 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.318906  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.319800  708041 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.372561  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.373315  708052 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.427533  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.428417  708063 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.478191  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.479094  708074 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.531715  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.532739  708085 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.580354  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.581272  708096 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.633743  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.634566  708107 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.683184  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.684162  708118 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.744116  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.745117  708129 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.801096  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.802146  708140 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.862342  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.863203  708151 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.911935  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.912747  708162 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341391.968812  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341391.969927  708173 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.033809  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.037062  708186 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.114454  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.115534  708206 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.180135  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.181288  708218 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.270359  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.271399  708229 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.333671  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.334541  708243 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.388338  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.389121  708254 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.441367  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.442189  708266 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.508780  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.509845  708279 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.556470  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.557319  708291 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.659057  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.660096  708304 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.712257  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.713132  708316 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.773108  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.774268  708329 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.843558  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.844479  708343 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.902543  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.903413  708354 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341392.969623  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341392.970541  708368 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.028805  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.029693  708379 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.087704  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.088517  708393 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.147386  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.148311  708404 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.206813  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.207670  708418 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.271443  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.272311  708429 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.339121  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.340070  708443 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.397600  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.398494  708454 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.451585  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.452487  708467 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.516323  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.517197  708479 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.566569  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.567482  708491 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.677305  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.678415  708505 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.726311  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.727336  708518 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.792703  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.798261  708532 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.850730  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.851735  708543 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.917906  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.918918  708557 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341393.979737  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341393.982826  708569 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.072184  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.074748  708582 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.139744  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.140961  708594 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.214741  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.215853  708608 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.280587  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.283114  708620 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.354236  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.355488  708633 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.408835  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.409806  708644 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.487231  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.488111  708658 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.546335  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.547628  708669 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.613068  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.614316  708683 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.678714  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.680235  708694 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.748310  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.749279  708707 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.815624  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.817028  708719 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.905038  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.906297  708742 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341394.985129  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341394.987695  708753 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.074088  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.075022  708767 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.125488  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.126465  708779 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.200047  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.200976  708793 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.262141  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.263154  708805 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.320452  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.321371  708819 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.368265  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.369043  708831 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.424507  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.425276  708844 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.470764  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.471568  708856 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.530817  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.531798  708869 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.582352  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.583289  708881 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.640358  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.641237  708894 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.689426  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.690445  708906 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.751546  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.752309  708919 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.807862  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.808732  708931 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341395.875216  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341395.876260  708944 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.337976  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.339257  708956 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.405898  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.406774  708969 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.471701  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.472585  708981 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.552318  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.553331  708995 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.611531  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.612442  709007 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.669873  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.671070  709020 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.721836  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.722765  709032 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.778308  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.781784  709045 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.829492  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.830487  709057 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341396.963190  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341396.964344  709071 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.037957  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.039155  709084 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.109474  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.110606  709096 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.164809  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.166223  709109 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.233886  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.236037  709121 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.307884  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.308989  709135 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.375646  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.376626  709147 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.431986  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.432953  709160 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.504549  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.507080  709172 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.571521  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.572782  709185 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.636253  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.639022  709197 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.695759  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.696823  709210 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.772226  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.774923  709222 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.837658  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.838834  709235 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.900673  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.901658  709247 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341397.962701  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341397.963732  709260 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.029733  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.031015  709272 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.097469  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.099077  709285 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.158649  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.159889  709296 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.227664  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.230158  709309 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.314128  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.315232  709321 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.383568  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.384865  709333 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.452918  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.453956  709346 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.505445  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.506522  709359 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.631435  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.632345  709374 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.680265  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.681054  709386 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.759910  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.760859  709399 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.810554  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.811441  709411 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.869591  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.870514  709424 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341398.930436  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341398.931761  709436 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.009198  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.010123  709449 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.063480  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.064331  709461 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.131130  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.132858  709474 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.190854  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.191761  709486 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.244665  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.245623  709499 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.306276  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.307300  709511 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.573842  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.574728  709524 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.624200  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.625170  709536 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.703819  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.704610  709549 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.757834  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.758626  709561 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.814147  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.814958  709574 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341399.867803  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341399.868798  709586 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.097087  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.098070  709599 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.150375  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.151395  709611 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.211247  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.212104  709624 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.268723  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.270035  709636 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.332919  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.333958  709649 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.395750  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.396774  709661 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.464974  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.466207  709674 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.513646  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.514512  709686 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.570826  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.572733  709699 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.622216  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.623189  709711 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341400.678868  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341400.679774  709724 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# ...
# I0000 00:00:1712341414.409904  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.411093  712125 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.485209  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.486504  712137 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.547365  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.548379  712150 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.618365  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.619446  712162 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.677758  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.678871  712175 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.755012  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.756067  712187 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.848218  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.849501  712200 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341414.939686  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341414.941111  712212 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.004656  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.005727  712225 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.085138  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.086446  712237 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.155075  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.156266  712250 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.249031  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.250387  712262 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.311629  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.312695  712275 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.387232  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.388137  712287 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.454035  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.455101  712300 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.538481  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.539763  712312 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.619624  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.620875  712325 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.700447  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.701772  712337 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.767756  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.770514  712350 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.854307  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.855385  712362 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341415.923804  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341415.925023  712375 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.050092  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.051230  712389 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.117383  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.118611  712400 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.205796  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.206949  712412 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.280642  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.282962  712425 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.353782  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.354896  712437 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.411705  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.412748  712450 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.477373  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.478466  712462 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.545094  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.546150  712475 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.615459  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.616485  712487 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.676583  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.677536  712500 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.744802  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.745878  712512 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.804105  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.805095  712525 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.876970  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.878108  712537 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341416.939747  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341416.940932  712550 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.006806  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.007781  712562 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.071485  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.072672  712575 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.151659  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.152920  712587 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.211423  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.212497  712600 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.284643  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.285738  712612 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.340211  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.341207  712625 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.414271  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.415245  712637 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.495245  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.496522  712650 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.616327  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.617275  712664 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.682934  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.684129  712676 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.754533  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.755734  712689 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.813627  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.814770  712701 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.893031  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.894616  712714 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341417.969269  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341417.970500  712726 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.041681  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.042878  712739 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.105043  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.106273  712751 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.175018  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.175994  712764 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.237809  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.238811  712776 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.306950  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.308106  712789 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.371600  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.373561  712800 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.469746  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.470975  712814 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# I0000 00:00:1712341418.532481  676802 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1712341418.533637  712825 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~23.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)

# %% [markdown]
# ## Display ALL landmark using mediapipe

# %%
import cv2
import mediapipe as mp

# Khởi tạo Face Mesh detection
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

# Đọc ảnh đầu vào
image_path = "frame_0000.jpg"
image = cv2.imread(image_path)

# Chuyển đổi ảnh sang không gian màu RGB (MediaPipe yêu cầu đầu vào là RGB)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Nhận diện landmark trên khuôn mặt
with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1) as face_mesh:
    results = face_mesh.process(image_rgb)
    if results.multi_face_landmarks:
        # Vẽ landmark lên ảnh
        # for face_landmarks in results.multi_face_landmarks:
        #     mp_drawing.draw_landmarks(
        #         image=image,
        #         landmark_list=face_landmarks,
        #         connections=mp_face_mesh.FACEMESH_TESSELATION,
        #         landmark_drawing_spec=None,
        #         connection_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=1, circle_radius=1),
        #     )

        # Hiển thị các điểm points_to_cut2
        points_to_cut2 = [464, 443, 265, 450]
        for idx in points_to_cut2:
            landmark = face_landmarks.landmark[idx]
            landmark_x = int(landmark.x * image.shape[1])
            landmark_y = int(landmark.y * image.shape[0])
            cv2.circle(image, (landmark_x, landmark_y), 3, (255, 0, 0), -1)

# Hiển thị ảnh với các điểm landmark
cv2.imshow("Face Landmarks", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Lua chon diem pixel

# %%
# import cv2

# # Hàm xử lý sự kiện click chuột
# def mouse_click(event, x, y, flags, param):
#     if event == cv2.EVENT_LBUTTONDOWN:
#         print(f"Coord (x, y): ({x}, {y})")

# # Đọc ảnh từ đường dẫn
# image = cv2.imread("frame1_0.jpg")

# # Kiểm tra xem ảnh có tồn tại không
# if image is None:
#     print("Không thể đọc ảnh. Hãy chắc chắn đường dẫn đến ảnh là chính xác.")
#     exit()

# # Tạo cửa sổ hiển thị ảnh
# cv2.namedWindow("Image")

# # Gán hàm xử lý sự kiện chuột cho cửa sổ hiển thị ảnh
# cv2.setMouseCallback("Image", mouse_click)

# # Hiển thị ảnh và đợi sự kiện từ người dùng
# while True:
#     cv2.imshow("Image", image)
#     key = cv2.waitKey(1) & 0xFF
#     # Nhấn 'q' để thoát
#     if key == ord('q'):
#         break

# # Giải phóng bộ nhớ và đóng cửa sổ
# cv2.destroyAllWindows()
